# %%
import numpy as np
from math import sqrt


x = [2,1,2]
y = [1,-1,4]

npX = np.array(x)
npY = np.array(y)

produs_scalar = 0
lungime_x = 0
lungime_y = 0
cos_unghi = 0
suma_x = 0 
i = 0 

for i in npX :
    suma_x=suma_x+i*i
    
lungime_X = sqrt(suma_x)

print ("Lungime X  =",lungime_X,"\n")

suma_y = 0
j = 0
for j in npY :
    suma_y=suma_y+j*j
    
lungime_Y = sqrt(suma_y)

print ("Lungime Y  =",lungime_Y,"\n")
# Out:
# Lungime X  = 3.0
#
# Lungime Y  = 4.242640687119285

# %%
p0 = [-1,-1,-1]
p1 = [-1,-1,1]
p2 = [-1,1,-1]
p3 = [-1,1,1]
p4 = [1,-1,1]
p5 = [1,-1,1]
p6 = [1,1,-1]
p7 = [1,1,1]
sgn_0 = 0 
sgn_1 = 0 
sgn_2 = 0 
sgn_3 = 0 
sgn_4 = 0 
sgn_5 = 0 
sgn_6 = 0 
sgn_7 = 0 

sgn_0 = p0[0]+p0[1]+p0[2]

if sgn_0 >= 0 :
    print ("SGN 0: 1")
elif sgn_0 < 0 :
    print("SGN 0: 2")

sgn_1 = p1[0]+p1[1]+p1[2]

if sgn_1 >= 0 :
    print ("SGN 1: 1")
elif sgn_1 < 0 :
    print("SGN 1: 2")
    
sgn_2 = p2[0]+p2[1]+p2[2]

if sgn_2 >= 0 :
    print ("SGN 2: 1")
elif sgn_2 < 0 :
    print("SGN 2: 2")
    
sgn_3 = p3[0]+p3[1]+p3[2]

if sgn_3 >= 0 :
    print ("SGN 3: 1")
elif sgn_3 < 0 :
    print("SGN 3: 2")
    
sgn_4 = p4[0]+p4[1]+p4[2]

if sgn_4 >= 0 :
    print ("SGN 4: 1")
elif sgn_4 < 0 :
    print("SGN 4: 2")
    
sgn_5 = p5[0]+p5[1]+p5[2]

if sgn_5 >= 0 :
    print ("SGN 5: 1")
elif sgn_5 < 0 :
    print("SGN 5: 2")
    
sgn_6 = p6[0]+p6[1]+p6[2]

if sgn_6 >= 0 :
    print ("SGN 6: 1")
elif sgn_6 < 0 :
    print("SGN 6: 2")
    
sgn_7 = p7[0]+p7[1]+p7[2]

if sgn_7 >= 0 :
    print ("SGN 7: 1")
elif sgn_7 < 0 :
    print("SGN 7: 2")
# Out:
# SGN 0: 2
# SGN 1: 2
# SGN 2: 2
# SGN 3: 1
# SGN 4: 1
# SGN 5: 1
# SGN 6: 1
# SGN 7: 1
